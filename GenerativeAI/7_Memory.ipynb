# %% [markdown]
# ### Agent with Memory

# %%
import os
from langchain.agents import create_agent
from langchain_google_genai import ChatGoogleGenerativeAI
os.environ["GOOGLE_API_KEY"] = os.getenv("GOOGLE_API_KEY")
model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
)

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

# %%
agent=create_agent(
    model=model,
    checkpointer=InMemorySaver()
)

# %%
# Run with thread ID

config={"configurable":{"thread_id":"test_01"}}

# %%
from langchain_core.messages import HumanMessage, SystemMessage
response=agent.invoke({"messages":[HumanMessage(content="Hi!! My name is Shivam")]}, config=config)
response
# Out:
# {'messages': [HumanMessage(content='Hi!! My name is Shivam', additional_kwargs={}, response_metadata={}, id='b9d36b93-e810-4a7d-b73b-d1da81fea08f'),
#   AIMessage(content="Hi Shivam! It's great to meet you.\n\nI'm an AI, a large language model developed by Google.\n\nHow can I help you today? Feel free to ask me anything!", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bdb72-e6b7-7181-b578-f8b9c085fa5c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 552, 'total_tokens': 560, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 510}})]}

# %%
agent.invoke({"messages":[HumanMessage(content="What is my name?")]}, config=config)
# Out:
# {'messages': [HumanMessage(content='Hi!! My name is Shivam', additional_kwargs={}, response_metadata={}, id='b9d36b93-e810-4a7d-b73b-d1da81fea08f'),
#   AIMessage(content="Hi Shivam! It's great to meet you.\n\nI'm an AI, a large language model developed by Google.\n\nHow can I help you today? Feel free to ask me anything!", additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019bdb72-e6b7-7181-b578-f8b9c085fa5c-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 8, 'output_tokens': 552, 'total_tokens': 560, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 510}}),
#   HumanMessage(content='What is my name?', additional_kwargs={}, response_metadata={}, id='154b9c18-c7af-4997-9766-648b02add6ea'),
# ...

# %% [markdown]
# It remembered my name :)
